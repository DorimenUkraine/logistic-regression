# %%
import numpy as np
from bokeh.plotting import figure, output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11b91052-bb1e-4624-83eb-3eca7a73c7e6">Loading BokehJS ...</span>
#     </div>

# %%
def generate_dataset(n):
    x = np.arange(n)
    res_x = []
    res_y = []
    for i in range(n):
        rand = 1/(1+np.exp(-i/n)**2)*(i/n)
        y_i = 1 if np.random.rand() < rand else 0
        res_x.append([1, x[i]])
        res_y.append(y_i)
    return np.array(res_x), np.array(res_y)

# %%
def proba(coef, x):
    return 1 / (1+np.exp(-x.dot(coef)))

# %%
def cross_entropy(coef, x, y):
    p = proba(coef, x)
    return -np.mean(y*np.log(p) + (1-y)*(1-p))

# %%
def gradient(coef, x, y):
    p = proba(coef, x)
    return -np.mean(y * x.transpose() / (1+np.exp(x.dot(coef))) - (1-y)*x.transpose()*p, axis=1)

# %%
def logistic_regression(coef, x, y, lr, epsilon=1e-4):
    prev_error = 0
    while True:
        error = cross_entropy(coef, x, y)
        if abs(error - prev_error) <= epsilon:
            break
        prev_error = error
        grad = gradient(coef, x, y)
        coef = np.subtract(coef, lr * grad)
    return coef

# %%
coef = np.array([0, 0])
x, y = generate_dataset(200)
p = figure()
p.scatter(x[:,1], y)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3e1c52ef-46b1-4859-9478-2dde612194c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3e1c52ef-46b1-4859-9478-2dde612194c8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3e1c52ef-46b1-4859-9478-2dde612194c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3e1c52ef-46b1-4859-9478-2dde612194c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f5efaee2-dadb-482d-a437-ea908d0677fd":{"roots":{"references":[{"attributes":{},"id":"52b51027-42df-4df0-be76-4eaa4dcabd16","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"c02a7118-4ed4-4646-a6b5-3c0ad6d16f4b","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc94d773-2e3b-4d0c-acae-45241f8f9a7f","type":"Circle"},{"attributes":{},"id":"ae314f3f-2321-4b41-9961-5931894eb0c0","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"640917cc-fd5d-43ce-ae3c-404c2e7bb17d","subtype":"Figure","type":"Plot"},"ticker":{"id":"57a2bf4d-0f0a-480b-9afe-3207710311d4","type":"BasicTicker"}},"id":"b9df5ba6-7dd1-43b2-896c-f4951cba0d53","type":"Grid"},{"attributes":{"overlay":{"id":"6eb9047d-986e-44f8-8b74-9f8f1ee33453","type":"BoxAnnotation"}},"id":"47f64b97-a19c-4f68-a33f-6f47d1e9b1c4","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"c304e1ff-d4e8-402b-9a36-16e2444b4435","type":"BasicTickFormatter"},"plot":{"id":"640917cc-fd5d-43ce-ae3c-404c2e7bb17d","subtype":"Figure","type":"Plot"},"ticker":{"id":"57a2bf4d-0f0a-480b-9afe-3207710311d4","type":"BasicTicker"}},"id":"ff1328b9-f10d-47b5-8b44-8dcc730c886f","type":"LinearAxis"},{"attributes":{},"id":"c304e1ff-d4e8-402b-9a36-16e2444b4435","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"int32","shape":[200]},"y":{"__ndarray__":"...","dtype":"int32","shape":[200]}}},"id":"00ee8cc9-ffb7-4b48-bbff-dd80f357ae06","type":"ColumnDataSource"},{"attributes":{},"id":"7c3c75f7-09d7-49b8-93bd-fbc0401e5341","type":"LinearScale"},{"attributes":{"below":[{"id":"93ec3217-e592-4c99-a8be-1f3bfdd35785","type":"LinearAxis"}],"left":[{"id":"ff1328b9-f10d-47b5-8b44-8dcc730c886f","type":"LinearAxis"}],"renderers":[{"id":"93ec3217-e592-4c99-a8be-1f3bfdd35785","type":"LinearAxis"},{"id":"a3a9195c-100c-4e1f-b937-606fc68bf347","type":"Grid"},{"id":"ff1328b9-f10d-47b5-8b44-8dcc730c886f","type":"LinearAxis"},{"id":"b9df5ba6-7dd1-43b2-896c-f4951cba0d53","type":"Grid"},{"id":"6eb9047d-986e-44f8-8b74-9f8f1ee33453","type":"BoxAnnotation"},{"id":"959d6031-f871-4294-86c9-f4037f1805e4","type":"GlyphRenderer"}],"title":{"id":"5d522689-8acb-4fa6-a292-cf230aea524d","type":"Title"},"toolbar":{"id":"89af145a-5eb6-4b66-b793-c67f44839433","type":"Toolbar"},"x_range":{"id":"9747b7c2-d664-4514-9bb4-9a50b7622ab6","type":"DataRange1d"},"x_scale":{"id":"7c3c75f7-09d7-49b8-93bd-fbc0401e5341","type":"LinearScale"},"y_range":{"id":"c02a7118-4ed4-4646-a6b5-3c0ad6d16f4b","type":"DataRange1d"},"y_scale":{"id":"ae314f3f-2321-4b41-9961-5931894eb0c0","type":"LinearScale"}},"id":"640917cc-fd5d-43ce-ae3c-404c2e7bb17d","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"9747b7c2-d664-4514-9bb4-9a50b7622ab6","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6eb9047d-986e-44f8-8b74-9f8f1ee33453","type":"BoxAnnotation"},{"attributes":{"source":{"id":"00ee8cc9-ffb7-4b48-bbff-dd80f357ae06","type":"ColumnDataSource"}},"id":"c4cbaacb-c055-4282-9f4b-716c2d95e6a1","type":"CDSView"},{"attributes":{"formatter":{"id":"52b51027-42df-4df0-be76-4eaa4dcabd16","type":"BasicTickFormatter"},"plot":{"id":"640917cc-fd5d-43ce-ae3c-404c2e7bb17d","subtype":"Figure","type":"Plot"},"ticker":{"id":"b03aa2f4-4df9-48b3-9c1a-4fee8fed7682","type":"BasicTicker"}},"id":"93ec3217-e592-4c99-a8be-1f3bfdd35785","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d3e301c-4ce2-4283-ae46-4044442662d6","type": ...

# %%
coef = logistic_regression(coef, x, y, 1e-2)

# %%
p = figure()
p.scatter(x[:,1], y)
p.line(x[:,1], proba(coef, x), color="orange")
show(p)
coef
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c66aeb86-8b01-4dbe-94f6-c695a1a8081b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c66aeb86-8b01-4dbe-94f6-c695a1a8081b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c66aeb86-8b01-4dbe-94f6-c695a1a8081b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c66aeb86-8b01-4dbe-94f6-c695a1a8081b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1cba1488-d6b3-4700-903e-011382455298":{"roots":{"references":[{"attributes":{"callback":null},"id":"cff203be-5051-48d5-806c-f58bb92fd062","type":"DataRange1d"},{"attributes":{},"id":"68fcdaee-e608-4cfc-90b6-968a270fcb1e","type":"LinearScale"},{"attributes":{},"id":"2b0d42eb-ce79-4685-81c9-6e26736f30f7","type":"BasicTicker"},{"attributes":{"formatter":{"id":"cada92f9-7b86-4b40-acea-ce1cdb232f95","type":"BasicTickFormatter"},"plot":{"id":"e736d13d-552e-425f-8ed2-ca995e9cca3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"